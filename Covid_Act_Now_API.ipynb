# %%
#Dependencies
import numpy as np
import pandas as pd
import json
import requests
from config import api_key
from pprint import pprint
from pandas_profiling import ProfileReport

# %%
url = "https://api.covidactnow.org/v2/county/MI.json?"

# Build query URL
query_url = f"{url}apiKey={api_key}"

# %%
# Current data for all states
covid_19_data = requests.get(query_url).json()

pprint(covid_19_data[0])
# Out:
# {'actuals': {'cases': 738,
#              'contactTracers': None,
#              'deaths': 32,
#              'hospitalBeds': {'capacity': None,
#                               'currentUsageCovid': None,
#                               'currentUsageTotal': None,
#                               'typicalUsageRate': None},
#              'icuBeds': {'capacity': None,
#                          'currentUsageCovid': None,
#                          'currentUsageTotal': None,
#                          'typicalUsageRate': None},
#              'negativeTests': None,
#              'newCases': 0,
#              'newDeaths': 0,
#              'positiveTests': None,
#              'vaccinationsCompleted': 4837,
#              'vaccinationsInitiated': 5118,
#              'vaccinationsInitiatedDemographics': None,
#              'vaccinesAdministered': 9955,
#              'vaccinesAdministeredDemographics': None,
#              'vaccinesDistributed': None},
#  'annotations': {'caseDensity': {'anomalies': [],
#                                  'sources': [{'name': 'The New York Times',
#                                               'type': 'NYTimes',
#                                               'url': 'https://github.com/nytimes/covid-19-data'}]},
#                  'cases': {'anomalies': [],
#                            'sources': [{'name': 'The New York Times',
#                                         'type': 'NYTimes',
#                                         'url': 'https://github.com/nytimes/covid-19-data'}]},
#                  'contactTracerCapacityRatio': None,
#                  'contactTracers': None,
#                  'deaths': {'anomalies': [],
#                             'sources': [{'name': 'The New York Times',
#                                          'type': 'NYTimes',
#                                          'url': 'https://github.com/nytimes/covid-19-data'}]},
#                  'hospitalBeds': None,
#                  'icuBeds': None,
#                  'icuCapacityRatio': None,
#                  'icuHeadroomRatio': None,
#                  'infectionRate': {'anomalies': [],
#                                    'sources': [{'name': 'The New York Times',
#                                                 'type': 'NYTimes',
#                                                 'url': 'https://github.com/nytimes/covid-19-data'}]},
#                  'infectionRateCI90': {'anomalies': [],
#                                        'sources': [{'name': 'The New York '
#                                                             'Times',
#                                                     'type': 'NYTimes',
#                                                     'url': 'https://github.com/nytimes/covid-19-data'}]},
#                  'negativeTests': None,
#                  'newCases': None,
#                  'newDeaths': None,
#                  'positiveTests': None,
#                  'testPositivityRatio': {'anomalies': [],
#                                          'sources': [{'name': 'Centers for '
#                                                               'Disease Control '
#                                                               'and Prevention',
#                                                       'type': 'CDCTesting',
#                                                       'url': 'https://covid.cdc.gov/covid-data-tracker/#county-view'}]},
#                  'vaccinationsCompleted': {'anomalies': [],
#                                            'sources': [{'name': 'State of '
#                                                                 'Michican '
#                                                                 'Official '
#                                                                 'Website',
#                                                         'type': 'CANScrapersStateProviders',
#                                                         'url': 'https://www.michigan.gov/coronavirus/0,9753,7-406-98178_103214_103272-547150--,00.html'}]},
#                  'vaccinationsCompletedRatio': None,
#                  'vaccinationsInitiated': {'anomalies': [],
#                                            'sources': [{'name': 'State of '
#                                                                 'Michican '
#                                                                 'Official '
#                                                                 'Website',
#                                                         'type': 'CANScrapersStateProviders',
#                                                         'url': 'https://www.michigan.gov/coronavirus/0,9753,7-406-98178_103214_103272-547150--,00.html'}]},
#                  'vaccinationsInitiatedRatio': None,
#                  'vaccinesAdministered': {'anomalies': [],
#                                           'sources': [{'name': 'State of '
#                                                                'Michican '
#                                                                'Official '
#                                                                'Website',
#                                                        'type': 'CANScrapersStateProviders',
#                                                        'url': 'https://www.michigan.gov/coronavirus/0,9753,7-406-98178_103214_103272-547150--,00.html'}]},
#                  'vaccinesDistributed': None},
#  'country': 'US',
#  'county': 'Alcona County',
#  'fips': '26001',
#  'lastUpdatedDate': '2021-06-08',
#  'lat': None,
#  'level': 'county',
#  'locationId': 'iso1:us#iso2:us-mi#fips:26001',
#  'long': None,
#  'metrics': {'caseDensity': 0.0,
#              'contactTracerCapacityRatio': None,
#              'icuCapacityRatio': None,
#              'icuHeadroomDetails': None,
#              'icuHeadroomRatio': None,
#              'infectionRate': 0.9663186702600001,
#              'infectionRateCI90': 1.1780920353899997,
#              'testPositivityRatio': 0.0104,
#              'testPositivityRatioDetails': {'source': 'other'},
#              'vaccinationsCompletedRatio': 0.46487265737626143,
#              'vaccinationsInitiatedRatio': 0.49187890437289766},
#  'population': 10405,
#  'riskLevels': {'caseDensity': 0,
#                 'contactTracerCapacityRatio': 4,
#                 'icuCapacityRatio': 4,
#                 'icuHeadroomRatio': 4,
#                 'infectionRate': 1,
#                 'overall': 0,
#                 'testPositivityRatio': 0},
#  'state': 'MI',
#  'url': 'https://covidactnow.org/us/michigan-mi/county/alcona_county'}

# %%
states_list = []
fips_list = []
county_list = []
populations = []
cases = []
vaccinations_Completed = []
vaccinations_Initiated = []

for x in covid_19_data:
    states_list.append(x['state'])  
    fips_list.append(x['fips'])  
    county_list.append(x['county']) 
    populations.append(x['population'])  
    cases.append(x['actuals']['cases'])
    vaccinations_Completed.append(x['actuals']['vaccinationsCompleted'])
    vaccinations_Initiated.append(x['actuals']['vaccinationsInitiated'])

# %%
# create dataframe
covid_19_df = pd.DataFrame({
    "State": states_list,
    "Fips" : fips_list,
    "County" : county_list,
    "Population": populations,
    "Total case (Current)" : cases,
    "Vaccination Completed" : vaccinations_Completed,
    "Vaccination Initiated" : vaccinations_Initiated
})
covid_19_df.head()
# Out:
#   State   Fips          County  Population  Total case (Current)  \
# 0    MI  26001   Alcona County       10405                   738
# 1    MI  26003    Alger County        9108                   667
# 2    MI  26005  Allegan County      118081                 11124
# 3    MI  26007   Alpena County       28405                  2262
# 4    MI  26009   Antrim County       23324                  1628
#
#    Vaccination Completed  Vaccination Initiated
# 0                   4837                   5118
# 1                   4407                   4879
# 2                  44289                  49703
# 3                  12404                  13210
# 4                  10661                  11609
